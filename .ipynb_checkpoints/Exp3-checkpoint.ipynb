# %% [markdown]
# # Experiencia 3 Inteligencia Computacional
# ### Detección de Movimiento
# ### Benjamín Irarrázabal y Joaquín Zepeda
# ### Profesor Claudio Pérez
# ### Auxiliar Juan Pablo Pérez

# %% [markdown]
# El siguiente notebook contiene el desarrollo de la tercera experiencia de laboratorio para el curso EL5206 “Laboratorio de Inteligencia Computacional y
# Robótica”, esta fue desarrollada durante dos semanas y se dividió en dos partes.
# La primera se basó en el análisis e implementación de dos algoritmos para de-
# tección de movimiento denominados diferencia de frames (Frame Differencing)
# y modelo de fondo(Averaging Background). Luego, se dió enfoque al tracking de
# personas basandose en Deep Learning utilizando los códigos facilitados por el
# equipo docente. Al final de este reporte se realiza una comparación entre ambos
# métodos, permitiendo observar sus diferencias y definiendo la mejor opción para
# este caso en específico.

# %% [markdown]
# **Es importante destacar que para el correcto funcionamiento del código el archivo (notebook) debe estar fuera de la carpeta Lab-Mov para que los caminos definidos a continuación sean correctos y las imágenes se carguen correctamente**

# %% [markdown]
# # Parte 1: Detección de movimiento con diferencia de frames y modelo de fondo

# %%
# Importamos librerías importantes
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob

# %%
# Creamos una lista que guardará las imágenes correspondientes a la primera secuencia 
path = glob.glob("Lab-Mov//seq1//seq1//*.jpg")
seq1 = [cv2.imread(file,0) for file in path]

# %%
# Creamos una lista que guardará las imágenes correspondientes a la segunda secuencia 
path2 = glob.glob("Lab-Mov//seq2//seq2//*.jpg")
seq2 = [cv2.imread(file,0) for file in path2]

# %%
# Creamos una lista que guardará las imágenes correspondientes a la tercera secuencia 
path3 = glob.glob("Lab-Mov//seq3//seq3//*.jpg")
seq3 = [cv2.imread(file,0) for file in path3]

# %%
# Creamos una lista que guardará las imágenes correspondientes al fondo
path7 = glob.glob("Lab-Mov//fondo//fondo//*.jpg")
fondo = [cv2.imread(file,0) for file in path7]

# %%
# Mostramos una imagen de prueba en escala de grises
a = seq1[0] 
plt.imshow(a,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1279.5, 799.5, -0.5)

# %%
# Probamos la resta de dos imágenes para comprobar la detección de movimiento
d=abs(seq1[300].astype(float) - seq1[0].astype(float))
plt.imshow(d,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1279.5, 799.5, -0.5)

# %%
d.shape
d=abs(seq1[300].astype(float) - seq1[0].astype(float))
threshold = 50
for j in range(d.shape[1]):
    for i in range(d.shape[0]):
        if d[i][j]>threshold:
            d[i][j] = 255
        else:
            d[i][j] = 0
plt.imshow(d,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1279.5, 799.5, -0.5)

# %% [markdown]
# ## Detección de movimiento por diferencia de cuadros

# %%
# Esta función calcula la diferencia de cuadros de toda la secuencia ingresada tomando un valor umbral definido por el usuario
def Frame_Diff(seq,umbral=50):
    Diff = []
    for i in range(1,len(seq)):
        Diff.append(abs(seq[i].astype(float) - seq[i-1].astype(float))) # Valor absoluto de la resta
    for i in range(len(Diff)):
        Diff[i] = cv2.inRange(Diff[i], umbral, 255)
    return Diff

# %% [markdown]
# ### Aplicamos la función a las primeras tres secuencias

# %%
FDs1 = Frame_Diff(seq1)

# %%
FDs2 = Frame_Diff(seq2)

# %%
FDs3 = Frame_Diff(seq3)

# %% [markdown]
# ### Mostramos ejemplos de cada secuencia

# %%
# Para la primera secuencia
fig = plt.figure(figsize=(10, 10))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1) 
plt.imshow(FDs1[13],cmap='gray') 
plt.axis('off') 
plt.title('Ejemplo 1, secuencia 1, Diferencia de Cuadros')

fig.add_subplot(rows, columns, 2) 
plt.imshow(FDs1[315], cmap='gray')
plt.axis('off')
plt.title('Ejemplo 2, secuencia 1, Diferencia de Cuadros')
# Out:
# Text(0.5, 1.0, 'Ejemplo 2, secuencia 1, Diferencia de Cuadros')

# %% [markdown]
# En las figuras anteriores se pueden observar dos objetos en movimiento. El primero corresponde a una paloma que pasa volando, mientras que el segundo corresponde a una persona que camina durante un par de frames.

# %%
# Para la segunda secuencia
fig = plt.figure(figsize=(10, 10))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1) 
plt.imshow(FDs2[58],cmap='gray') 
plt.axis('off') 
plt.title('Ejemplo 1, secuencia 2, Diferencia de Cuadros')

fig.add_subplot(rows, columns, 2) 
plt.imshow(FDs2[291], cmap='gray')
plt.axis('off')
plt.title('Ejemplo 2, secuencia 2, Diferencia de Cuadros')
# Out:
# Text(0.5, 1.0, 'Ejemplo 2, secuencia 2, Diferencia de Cuadros')

# %% [markdown]
# A partir de la observación de la carpeta respectiva a la secuencia 2 se extrae que el objeto en movimiento que se aprecia en las figuras anteriores corresponde a un ciclista. Si bien el algoritmo logra detectar correctamente el movimiento en esta ocasión no se logra distinguir a simple vista qué es lo que está circulando.

# %%
# Para la tercera secuencia
fig = plt.figure(figsize=(10, 10))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1) 
plt.imshow(FDs3[75],cmap='gray') 
plt.axis('off') 
plt.title('Ejemplo 1, secuencia 3, Diferencia de Cuadros')

fig.add_subplot(rows, columns, 2) 
plt.imshow(FDs3[122], cmap='gray')
plt.axis('off')
plt.title('Ejemplo 2, secuencia 3, Diferencia de Cuadros')
# Out:
# Text(0.5, 1.0, 'Ejemplo 2, secuencia 3, Diferencia de Cuadros')

# %% [markdown]
# Al igual que en el análisis anterior, en este caso no se aprecia la naturaleza del objeto pero el algoritmo logra detectar correctamente el movimiento. \
# Como comentario general, cabe destacar que en la segunda y tercera secuencia el movimiento entre frames debe ser considerablemente menor, por este motivo el algoritmo lo detecta pero no se aprecia un cuerpo definido mostrando una imagen con poco porcentaje de blancos.

# %% [markdown]
# ## Detección de Movimiento por modelo de fondo

# %% [markdown]
# ### Obtenemos el promedio y la desviación del fondo y mostramos la imagen y matriz correspondiente

# %%
# Calculamos el promedio y desviación estándar del fondo (ámbos pixel a pixel)
mean_fondo = np.mean(fondo, axis=0)
std_fondo = np.std(fondo, axis=0)

fig = plt.figure(figsize=(10, 10))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1) 
plt.imshow(mean_fondo,cmap='gray')
plt.axis('off')
plt.title('promedio pixel a pixel del fondo')

fig.add_subplot(rows, columns, 2) 
plt.imshow(std_fondo,cmap='gray')
plt.axis('off')
plt.title('desviación pixel a pixel del fondo')
# Out:
# Text(0.5, 1.0, 'desviación pixel a pixel del fondo')

# %%
# Entregamos la matriz 1 correspondiente al promedio del fondo:
print(mean_fondo)
# Out:
# [[ 85.96        85.86857143  85.78857143 ... 145.61142857 144.80571429
#   144.39428571]
#  [ 85.86857143  85.81714286  85.74285714 ... 145.36       144.38285714
#   144.13714286]
#  [ 85.01714286  84.97142857  84.89142857 ... 144.92       143.95428571
#   143.55428571]
#  ...
#  [113.60571429 113.41714286 113.21714286 ... 141.65714286 141.25142857
#   140.35428571]
#  [112.44       112.45142857 112.21714286 ... 139.2        138.04571429
#   136.78285714]
#  [111.52       111.37142857 111.30285714 ... 137.53714286 136.17714286
#   134.76571429]]

# %%
# Entregamos la matriz 2 correspondiente a la desviación del fondo:
print(std_fondo)
# Out:
# [[2.48046079 2.35429958 2.24394696 ... 4.61400176 4.76858427 4.93604485]
#  [2.35429958 2.30049507 2.20574389 ... 4.62435787 4.69610694 4.96427729]
#  [2.28153904 2.2282051  2.14999953 ... 4.70190235 4.7926338  5.0229384 ]
#  ...
#  [2.3370241  2.20978159 2.03083174 ... 2.61143482 2.86748984 3.48222776]
#  [2.21568435 2.2004378  2.03364356 ... 2.97993289 3.27382196 3.67209444]
#  [2.7730128  2.63694319 2.56676402 ... 3.57571857 3.92319736 4.47558091]]

# %%
def Av_Back(fondo, threshold, seq):
    X = np.mean(fondo, axis=0) # Promedio
    D = np.std(fondo, axis=0) # Desviación
    L1 = X + threshold * (D + 1) # Límite 1
    L2 = X - threshold * (D + 1) # Límite 2
    Back = [] # Lista que guarda el resultado
    M = []
    for k in range(len(seq)):
        mask_bool = np.logical_or(seq[k] > L1, seq[k] < L2)
        M.append(mask_bool)
    for k in range(len(M)):
        M[k] = np.array(M[k])*255
    return M

# %% [markdown]
# ### Aplicamos la función a las primeras tres secuencias

# %%
ABs1 = Av_Back(fondo, 20, seq1)

# %%
ABs2 = Av_Back(fondo, 20, seq2)

# %%
ABs3 = Av_Back(fondo, 20, seq3)

# %% [markdown]
# ### Mostramos ejemplos de cada secuencia

# %%
# Para la primera secuencia
fig = plt.figure(figsize=(10, 10))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1) 
plt.imshow(ABs1[14],cmap='gray') 
plt.axis('off') 
plt.title('Ejemplo 1, secuencia 1, Modelo de Fondo')

fig.add_subplot(rows, columns, 2) 
plt.imshow(ABs1[315], cmap='gray')
plt.axis('off')
plt.title('Ejemplo 2, secuencia 1, Modelo de Fondo')
# Out:
# Text(0.5, 1.0, 'Ejemplo 2, secuencia 1, Modelo de Fondo')

# %% [markdown]
# En los ejemplos mostrados anteriormente se detecta el movimiento de forma eficiente alcanzando a distinguir la naturaleza del cuerpo que circula.

# %%
# Para la segunda secuencia
fig = plt.figure(figsize=(10, 10))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1) 
plt.imshow(ABs2[58],cmap='gray') 
plt.axis('off') 
plt.title('Ejemplo 1, secuencia 2, Modelo de Fondo')

fig.add_subplot(rows, columns, 2) 
plt.imshow(ABs2[291], cmap='gray')
plt.axis('off')
plt.title('Ejemplo 2, secuencia 2, Modelo de Fondo')
# Out:
# Text(0.5, 1.0, 'Ejemplo 2, secuencia 2, Modelo de Fondo')

# %% [markdown]
# Al observar los ejemplos y compararlos con los obtenidos para la diferencia de cuadros se observa una clara mejora al usar este algoritmo, permitiendo detectar de mejor manera el objeto y distinguir su forma.

# %%
# Para la tercera secuencia
fig = plt.figure(figsize=(10, 10))
rows = 1
columns = 2

fig.add_subplot(rows, columns, 1) 
plt.imshow(ABs3[82],cmap='gray') 
plt.axis('off') 
plt.title('Ejemplo 1, secuencia 3, Modelo de Fondo')

fig.add_subplot(rows, columns, 2) 
plt.imshow(ABs3[122], cmap='gray')
plt.axis('off')
plt.title('Ejemplo 2, secuencia 3, Modelo de Fondo')
# Out:
# Text(0.5, 1.0, 'Ejemplo 2, secuencia 3, Modelo de Fondo')

# %% [markdown]
# Si bien en estos ejemplos se puede detectar el movimiento, el cuerpo es casi indistinguible, esto puede mejorarse pero existe un trade-off entre la mejora de la detección y el ruido que aparece en la imagen, ya que al disminuir el umbral, el cuerpo en movimiento se hace más visible pero aumenta el ruido generado alrededor de este (puntos o manchas blancas), por lo tanto, se debe buscar un balance entre esto, ya que en la siguiente sección (box detection), este ruido afecta directamente al dibujo del blob de detección.

# %% [markdown]
# # Box detection

# %%
# Se define la función que recibe una imagen y le aplica su respectivo blob de detección
def draw_box(img,line = 4,title='imagen',factor_umbral = 2,figsize=(8,16)):
    M = img
    # Histogramas
    Hist_cols = np.sum(M,axis=0)
    Hist_rows = np.sum(M,axis=1)
    x = []
    y = []

    for i in range(len(Hist_cols)):
        if Hist_cols[i] > factor_umbral*np.mean(Hist_cols):
            x.append(i)
        else:
            pass
    for j in range(len(Hist_rows)):
        if Hist_rows[j] > factor_umbral*np.mean(Hist_rows):
            y.append(j)
        else:
            pass
    minx = np.min(x)
    maxx = np.max(x)
    miny = np.min(y)
    maxy = np.max(y)

    M = M.astype(np.uint8)
    M_rgb = cv2.merge([M,M,M])
    
    # dibujamos el box
    cv2.rectangle(M_rgb,(minx,miny),(maxx,maxy),(153, 102, 204),4)

    plt.figure(figsize=(8,16))
    plt.imshow(M_rgb)
    plt.title(title)
    plt.axis('off')

# %%
draw_box(ABs1[312],title='reconocimiento de movimiento')

# %% [markdown]
# Tracking simple de personas

# %%
# usemos una secuencia concida para determinar los parametros A,B,C,D
#que seran utilizados para realziar un tracking simple

# probemos usando desde el 180 hasta el 250 de seq1
plt.imshow(ABs1[100],cmap='gray')
plt.title('Imagen sin blob de detección')
plt.axis('off')
# Out:
# (-0.5, 1279.5, 799.5, -0.5)

# %% [markdown]
# ## seccionamos una secuencia para determinar los parametros

# %%
seq_train = ABs1[180:250]

# %%
#Extraemos los datos de los cuadros correspondientes a la secuencia concida
minx_train,maxx_train = [], []
miny_train,maxy_train = [], []

for M in seq_train:

    # Histogramas
    Hist_cols = np.sum(M,axis=0)
    Hist_rows = np.sum(M,axis=1)
    x = []
    y = []

    for i in range(len(Hist_cols)):
        if Hist_cols[i] > 2*np.mean(Hist_cols):
            x.append(i)
        else:
            pass
    for j in range(len(Hist_rows)):
        if Hist_rows[j] > 2*np.mean(Hist_rows):
            y.append(j)
        else:
            pass
    minx_train.append(np.min(x))
    maxx_train.append(np.max(x))
    miny_train.append(np.min(y))
    maxy_train.append(np.max(y))

# %%
#Creamos los inputs y outputs correspondientes para luego estimar los parametros
inputs1 = []
inputs2 = []
outputs = []
for i in range(1,len(minx_train)-1):
    inputs1.append([minx_train[i-1],maxx_train[i-1],miny_train[i-1],maxy_train[i-1]])
    inputs2.append([minx_train[i],maxx_train[i],miny_train[i],maxy_train[i]])
    outputs.append([minx_train[i+1],maxx_train[i+1],miny_train[i+1],maxy_train[i+1]])

# %%
inputs1[0],inputs2[0],outputs[0]
# Out:
# ([1058, 1170, 351, 439], [1058, 1169, 353, 439], [1058, 1167, 357, 439])

# %%
"""
h3 = h2 + A*(h2-h1) -> A = (h3-h2)/(h2-h1) minx
w3 = w2 + B*(w2-w1) -> B = (w3-w2)/(w2-w1) maxx
x3 = x2 + C*(x2-x1) -> C = (x3-x2)/(x2-x1) miny
y3 = y2 + D*(y2-y1) -> D = (y3-y2)/(y2-y1) maxy
"""
A_array = []
B_array = []
C_array = []
D_array = []
for L1,L2,L3 in zip(inputs1,inputs2,outputs):
    h1,h2,h3 = L1[0],L2[0],L3[0]
    w1,w2,w3 = L1[1],L2[1],L3[1]
    x1,x2,x3 = L1[2],L2[2],L3[2]
    y1,y2,y3 = L1[3],L2[3],L3[3]
    if h2-h1 != 0:
        A_array.append((h3-h2)/(h2-h1))
    if w2-w1 != 0:
        B_array.append((w3-w2)/(w2-w1))
    if x2-x1 != 0:
        C_array.append((x3-x2)/(x2-x1))
    if y2-y1:
        D_array.append((y3-y2)/(y2-y1))
        
# Estimamos los parametros usando el promedio de los parametros encontrados para cada frame
A = np.mean(A_array)
B = np.mean(B_array)
C = np.mean(C_array)
D = np.mean(D_array)
print("A:",A,"B:",B,"C:",C,"D:",D)
# Out:
# A: 0.5681818181818182 B: 0.6944444444444444 C: 1.2911616161616162 D: 0.8825640942182295

# %%
# L_min% y L_max% tienen que tener los dos valores min% y max% respectivamente anteriores
def pred_box(img,L_minx,L_maxx,L_miny,L_maxy):
    #-----------------------------------------------------------------------------
    # usando el modelo de tracking simple
    M=img

    minx = int(L_minx[-1] + A*(L_minx[-1]-L_minx[-2]))
    maxx = int(L_maxx[-1] + B*(L_maxx[-1]-L_maxx[-2]))
    miny = int(L_miny[-1] + C*(L_miny[-1]-L_miny[-2]))
    maxy = int(L_maxy[-1] + D*(L_maxy[-1]-L_maxy[-2]))

    M = M.astype(np.uint8)
    M_rgb = cv2.merge([M,M,M])
    cv2.rectangle(M_rgb,(minx,miny),(maxx,maxy),(200, 50, 50),4)

    plt.figure(figsize=(16,18))
    plt.imshow(M_rgb)
    plt.title('Imagen')
    plt.axis('off')
    return (minx,miny),(maxx,maxy)

# %% [markdown]
# # TEST

# %%
#-----------------------------------------------------------------------------
# usando el modelo de tracking simple

# Buscamos predecir la ubicación de la persona en la ultima posición, correspondiente al seq_train[-1],
# esto a partir de los valores de la caja en el instante -2 y -3 los cuales serían los 2 anteriores.
minx = int(minx_train[-2] + A*(minx_train[-2]-minx_train[-3]))
maxx = int(maxx_train[-2] + B*(maxx_train[-2]-maxx_train[-3]))
miny = int(miny_train[-2] + C*(miny_train[-2]-miny_train[-3]))
maxy = int(maxy_train[-2] + D*(maxy_train[-2]-maxy_train[-3]))

M = seq_train[-1]
M = M.astype(np.uint8)
M_rgb = cv2.merge([M,M,M])
cv2.rectangle(M_rgb,(minx_train[-1],miny_train[-1]),(maxx_train[-1],maxy_train[-1]),(153, 102, 204),4)
cv2.rectangle(M_rgb,(minx,miny),(maxx,maxy),(200, 50, 50),4)

plt.figure(figsize=(16,18))
plt.imshow(M_rgb)
plt.title('En azul la predicción, en rojo el cuadro real',fontsize=16)
plt.axis('off')
# Out:
# (-0.5, 1279.5, 799.5, -0.5)

# %%
# Probemos con otro instante 
# Predecir la box del frame 200 

# 

#-----------------------------------------------------------------------------
# usando el modelo de tracking simple

x = 200
j = 180 #valor donde comienza la secuencia conocida seq_train = ABs1[180:250]

# EL frame 200 corresponde al seq_train[20], pues comienza desde el 180

minx = int(minx_train[x-j-1] + A*(minx_train[x-j-1]-minx_train[x-j-2]))
maxx = int(maxx_train[x-j-1] + B*(maxx_train[x-j-1]-maxx_train[x-j-2]))
miny = int(miny_train[x-j-1] + C*(miny_train[x-j-1]-miny_train[x-j-2]))
maxy = int(maxy_train[x-j-1] + D*(maxy_train[x-j-1]-maxy_train[x-j-2]))

M = seq_train[x-j]
M = M.astype(np.uint8)
M_rgb = cv2.merge([M,M,M])
cv2.rectangle(M_rgb,(minx_train[x-j],miny_train[x-j]),(maxx_train[x-j],maxy_train[x-j]),(153, 102, 204),4)
cv2.rectangle(M_rgb,(minx,miny),(maxx,maxy),(200, 50, 50),4)

plt.figure(figsize=(16,18))
plt.imshow(M_rgb)
plt.title('En azul la predicción, en rojo el cuadro real',fontsize=16)
plt.axis('off')
# Out:
# (-0.5, 1279.5, 799.5, -0.5)

# %%
#----------------------------------------------------------------------------------------

# %%
# Creamos una lista que guardará las imágenes correspondientes a la primera secuencia 
path = glob.glob("Lab-Mov//seq4//seq4//*.bmp")
path.sort(key=lambda x: int((x.split(".")[0].split('\\')[1].split("-")[1]))) # reordena los frames

seq4 = [cv2.imread(file,0) for file in path]


# Creamos una lista que guardará las imágenes correspondientes a la primera secuencia 
path = glob.glob("Lab-Mov//seq5//seq5//*.bmp")
path.sort(key=lambda x: int((x.split(".")[0].split('\\')[1].split("-")[1]))) # reordena los frames

seq5 = [cv2.imread(file,0) for file in path]

# Creamos una lista que guardará las imágenes correspondientes a la primera secuencia 
path = glob.glob("Lab-Mov//seq6//seq6//*.bmp")
path.sort(key=lambda x: int((x.split(".")[0].split('\\')[1].split("-")[1]))) # reordena los frames

seq6 = [cv2.imread(file,0) for file in path]

# %%
plt.imshow(cv2.cvtColor(seq4[200], cv2.COLOR_BGR2RGB),cmap='gray')
plt.title('Imagen sin blob de detección')
plt.axis('off')
# Out:
# (-0.5, 351.5, 287.5, -0.5)

# %%
# Utilizamos la funcion diferencia de cuadros para detectar movimientos en las secuencias
FDs4 = Frame_Diff(seq4,60)
FDs5 = Frame_Diff(seq5,60)
FDs6 = Frame_Diff(seq6,80)

# %% [markdown]
# # Detección de movimiento por diferencia de cuadros para las secuencias seq4,seq5,seq6

# %% [markdown]
# Como se puede observar en las siguientes imagenes, la detección de movimiento para las secuencias seq4 y seq5 funciona relativamente bien, esto pues el video es estable. Por otro lado para la secuencia seq6 en donde hay movimiento en la camara se observa que no es posible detectar el box de la persona pues se produce mucho ruido.

# %%
draw_box(FDs4[320],title='Detección de movimiento por diferencia de cuadros \nseq4',factor_umbral=4)
draw_box(FDs5[180],title='Detección de movimiento por diferencia de cuadros \nseq5',factor_umbral=3)
draw_box(FDs6[180],title='Detección de movimiento por diferencia de cuadros \nseq6',factor_umbral=3)

# %%
seq_test = seq4[230:320]
